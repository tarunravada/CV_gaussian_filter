# %% [markdown]
# # ITCS 4152 Project 1 - Image Filtering
# ### Tarun Ravada
# For this project I am implemeting a system that applies a Gaussian blur over an RGB image. This notebook will serve as an interface to load and view images. The algorithms for applying the filter and kernel generation have been implemented in a seperate python file and imported to this notebook.

# %%
from image_filtering import gaussian_blur
from IPython.display import display, Image

# %% [markdown]
# #### The gaussian_blur method takes 3 parameters
#         image - directory of the image to filter
#         sigma - sigma size to use for the gaussian filter
#         k_size - size of the filter or kernel

# %% [markdown]
# #### Set initial parameters and call the guassian_blur function. The original image and fitered image will be displayed below.

# %%
# set the directory of the target image
img_directory = r'images\council.jpg'

# larger sigma value leads to more blurry image
sigma = 5
size = int(4 * sigma ) + 1

original_image = Image(filename=img_directory)
filtered_image = gaussian_blur(img_directory, sigma, size)

# %% [markdown]
# #### Orignal Image

# %%
display(original_image)

# %% [markdown]
# #### Filtered image

# %%
display(filtered_image)
# Out:
# <PIL.Image.Image image mode=RGB size=600x443 at 0x209AED15198>
